# %%
import pandas as pd, numpy as np, seaborn as sns, matplotlib.pyplot as plt

# %%
df = pd.read_csv('Train.csv')
df2 = pd.read_csv('Test.csv')

# %%
df.head()
# Out:
#         Place_ID X Date        Date Place_ID  target  target_min  target_max  \
# 0  010Q650 X 2020-01-02  2020-01-02  010Q650    38.0        23.0        53.0
# 1  010Q650 X 2020-01-03  2020-01-03  010Q650    39.0        25.0        63.0
# 2  010Q650 X 2020-01-04  2020-01-04  010Q650    24.0         8.0        56.0
# 3  010Q650 X 2020-01-05  2020-01-05  010Q650    49.0        10.0        55.0
# 4  010Q650 X 2020-01-06  2020-01-06  010Q650    21.0         9.0        52.0
#
#    target_variance  target_count  precipitable_water_entire_atmosphere  \
# 0           769.50            92                             11.000000
# 1          1319.85            91                             14.600000
# 2          1181.96            96                             16.400000
# 3          1113.67            96                              6.911948
# 4          1164.82            95                             13.900001
#
#    relative_humidity_2m_above_ground  ...  L3_SO2_sensor_zenith_angle  \
# ...

# %%
df2
# Out:
#         Place_ID X Date        Date Place_ID  \
# 0  0OS9LVX X 2020-01-02  2020-01-02  0OS9LVX
# 1  0OS9LVX X 2020-01-03  2020-01-03  0OS9LVX
# 2  0OS9LVX X 2020-01-04  2020-01-04  0OS9LVX
# 3  0OS9LVX X 2020-01-05  2020-01-05  0OS9LVX
# 4  0OS9LVX X 2020-01-06  2020-01-06  0OS9LVX
#
#    precipitable_water_entire_atmosphere  relative_humidity_2m_above_ground  \
# 0                             11.600000                          30.200001
# 1                             18.300001                          42.900002
# 2                             17.600000                          41.299999
# 3                             15.011948                          53.100002
# 4                              9.700000                          71.599998
#
#    specific_humidity_2m_above_ground  temperature_2m_above_ground  \
# 0                            0.00409                    14.656824
# 1                            0.00595                    15.026544
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30557 entries, 0 to 30556
# Data columns (total 82 columns):
#  #   Column                                               Non-Null Count  Dtype
# ---  ------                                               --------------  -----
#  0   Place_ID X Date                                      30557 non-null  object
#  1   Date                                                 30557 non-null  object
#  2   Place_ID                                             30557 non-null  object
#  3   target                                               30557 non-null  float64
#  4   target_min                                           30557 non-null  float64
#  5   target_max                                           30557 non-null  float64
#  6   target_variance                                      30557 non-null  float64
#  7   target_count                                         30557 non-null  int64
# ...

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
#dropping all columns and rows with more than 70% NA Values
print('Shape Before Dropping', df.shape)
df.dropna(axis=1, thresh=int(0.3 * df.shape[0]), inplace=True)
df.dropna(axis=0, thresh=int(0.3 * df.shape[1]), inplace=True)
print('Shape After Dropping', df.shape)
# Out:
# Shape Before Dropping (30557, 82)
# Shape After Dropping (30398, 75)

# %%
#printing all columns with na values, with their corresponding datatype
cols_with_na = df.columns[(1 - df.count()/df.shape[0]) > 0]
df[cols_with_na].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 30398 entries, 0 to 30555
# Data columns (total 61 columns):
#  #   Column                                               Non-Null Count  Dtype
# ---  ------                                               --------------  -----
#  0   L3_NO2_NO2_column_number_density                     28367 non-null  float64
#  1   L3_NO2_NO2_slant_column_number_density               28367 non-null  float64
#  2   L3_NO2_absorbing_aerosol_index                       28367 non-null  float64
#  3   L3_NO2_cloud_fraction                                28367 non-null  float64
#  4   L3_NO2_sensor_altitude                               28367 non-null  float64
#  5   L3_NO2_sensor_azimuth_angle                          28367 non-null  float64
#  6   L3_NO2_sensor_zenith_angle                           28367 non-null  float64
#  7   L3_NO2_solar_azimuth_angle                           28367 non-null  float64
# ...

# %%
#filling the missing values of each feature with its respective mean
from sklearn.impute import SimpleImputer
imp = SimpleImputer(missing_values=np.nan, strategy='mean')
df[cols_with_na] = imp.fit_transform(df[cols_with_na])

# %%
#printing all columns with na values again, with their corresponding datatype, this should give an empty result
cols_with_na = df.columns[(1 - df.count()/df.shape[0]) > 0] 
df[cols_with_na].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 30398 entries, 0 to 30555
# Empty DataFrame

# %%
needed_date_features = ['year', 'month', 'day']
for item in needed_date_features:
    df[item] = getattr(df['Date'].dt, item)

# %%
# sns.lineplot(data=df, x="day", y="target")

# %%
# sns.lineplot(data=df, x="month", y="target")

# %%
target_features = ['target', 'target_min','target_max', 'target_variance', 'target_count']
to_be_removed = ['Place_ID X Date', 'Date', 'Place_ID']
working_df = df.copy()

# %%
X = working_df.drop(target_features + to_be_removed, axis=1)
y = working_df['target']

# %%
predicting_features = X.columns

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# %%
# #Working with outliers
# print('before outlier removal', X_train.shape)
# from sklearn.covariance import EllipticEnvelope
# from sklearn.ensemble import IsolationForest
# iso = EllipticEnvelope(contamination=0.01)
# yhat = iso.fit_predict(X_train)
# mask = yhat != -1
# y_train = y_train[mask]
# X_train = X_train[mask]
# print('after outlier removal', X_train.shape)

# %%
from sklearn.preprocessing import MinMaxScaler, StandardScaler
#Standardizing the data
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
# #Performing PCA
# from sklearn.decomposition import PCA
# pca = PCA(n_components=70)
# X = pca.fit_transform(X)

# %%
# sum(pca.explained_variance_ratio_)

# %%
from lightgbm import LGBMRegressor

# %%
model = LGBMRegressor(random_state=100)
model.fit(X_train, y_train)
prediction = model.predict(X_test)
prediction_df = pd.DataFrame(data=np.hstack([y_test.values.reshape(-1,1), prediction.reshape(-1,1)]), columns=["Actual Value", "Predicted Value"])
prediction_df.head(10)
# Out:
#    Actual Value  Predicted Value
# 0          22.0        41.711407
# 1          26.0        42.137212
# 2         105.0        59.414115
# 3         153.0       119.933660
# 4          27.0        48.451131
# 5          15.0        33.879738
# 6          63.0        67.987584
# 7          15.0        28.430011
# 8          85.0        67.878371
# 9          13.0        55.239275

# %%
from sklearn.metrics import mean_squared_error

# %%
print("MSE Score", mean_squared_error(y_test,prediction))
print("RMSE Score", mean_squared_error(y_test,prediction)**0.5)
# Out:
# MSE Score 1016.454033447914
# RMSE Score 31.881876253569423

# %%
# df_imp = pd.DataFrame(columns=["label","importance"], data=item_feat_imp).sort_values(by="importance", ascending=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-8e355a94133a> in <module>
# ----> 1 df_imp = pd.DataFrame(columns=["label","importance"], data=item_feat_imp).sort_values(by="importance", ascending=False)
#
# NameError: name 'item_feat_imp' is not defined
